# %% [markdown]
# Lists

# %% [markdown]
# Find the First Missing Positive

# %%
# Wrong
def first_missing_positive(numbers):
    numbers=sorted(numbers)
    miss=[]
    for i in range(len(numbers)):
        if numbers[i]!=i:
            miss.append(i)
            
    return miss
            
first_missing_positive([1, 2, 0])  
first_missing_positive([3, 4, -1, 1])
# Out:
# [0, 2, 3]

# %%
def first_missing_positive(numbers):
    numbers = sorted(numbers)

    positive = 1

    for number in numbers:
        if number == positive:
            positive += 1
        elif number > positive:
            return positive

    return positive

print(first_missing_positive([1, 2, 0]))
print(first_missing_positive([3, 4, -1, 1]))
# Out:
# 3
# 2

# %%
def first_missing_positive(numbers):
    positive = 1

    while positive in numbers:
        positive += 1

    return positive

print(first_missing_positive([1, 2, 0]))
print(first_missing_positive([3, 4, -1, 1]))
# Out:
# 3
# 2

# %% [markdown]
# Different Pattern
# Challenge: Find the Longest Word

# %%
def longest_word(text):
    text=text.split()
    longest=len(text)
    word=""
    
    for i in text:
        if len(i)>longest:
            longest=len(i)
            word=i
            
    return word
        
longest_word("I love learning Python")
longest_word("Python is powerful")
# Out:
# 'powerful'

# %%
def longest_word(text):
    word=""
    
    for i in text.split():
        if len(i)>len(word):
            word=i
            
    return word
        
longest_word("I love learning Python")
longest_word("Python is powerful")
# Out:
# 'powerful'

# %% [markdown]
# Find the Majority Element

# %%
#freq
def majority_element(numbers):
    count=0
    new={}
    for i in numbers:
        if i in new:
            new[i]+=1
        else:
            new[i]=1

    return new    
majority_element([2, 2, 1, 2, 3, 2, 2])
# Out:
# {2: 5, 1: 1, 3: 1}

# %%
def majority_element(numbers):
    new={}
    for i in numbers:
        if i in new:
            new[i]+=1
        else:
            new[i]=1
    
    for i in new:
        if new[i] > len(numbers) // 2:
            return i
        
majority_element([2, 2, 1, 2, 3, 2, 2])
# Out:
# 2

# %% [markdown]
# Strings

# %% [markdown]
# Longest Substring Without Repeating Characters

# %%
def longest_unique_substring(text):
    seen = {}
    left = 0
    longest = 0

    for right in range(len(text)):
        char = text[right]

    return longest

# %%
def longest_unique_substring(text):
    seen = {}
    left = 0
    longest = 0

    for right in range(len(text)):
        char = text[right]

        if char in seen and seen[char] >= left:
            left = seen[char] + 1

        seen[char] = right

        current_length = right - left + 1

        if current_length > longest:
            longest = current_length

    return longest


longest_unique_substring("abcabcbb")
longest_unique_substring("bbbbb")
longest_unique_substring("pwwkew")
# Out:
# 3
