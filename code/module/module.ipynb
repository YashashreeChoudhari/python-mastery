# %%
import math
print(math.sqrt(25))
# Out:
# 5.0

# %%
import random
print(random.randint(1, 10))
# Out:
# 9

# %%
import math
print(math.floor(7.9))

math.floor(7.9)  
math.ceil(7.1)
# Out:
# 7
# 8

# %%
from datetime import date
today = date.today()
print(today)
# Out:
# 2026-08-17
